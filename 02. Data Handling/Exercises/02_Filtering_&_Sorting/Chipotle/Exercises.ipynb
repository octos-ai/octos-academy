# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv", sep='\t')
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
#Quantidade de produtos distintos pelo "item_name"
len(chipo['item_name'].value_counts().index)
# Out:
# 50

# %%
chipo['item_price'] = chipo['item_price'].apply(lambda x: str(x).replace('$','')).astype('float64')

# %%
#Encontrar apenas os pedidos com 1 quantidade
dataframe_novo1 = chipo.loc[chipo['quantity']==1]

#Selecionar, dentre esses pedidos, aqueles que custam mais de 10
dataframe_novo2 = dataframe_novo1.loc[dataframe_novo1['item_price']>10.0]
dataframe_novo2
# Out:
#       order_id  quantity           item_name  \
# 5            3         1        Chicken Bowl
# 7            4         1       Steak Burrito
# 13           7         1        Chicken Bowl
# 23          12         1     Chicken Burrito
# 39          19         1       Barbacoa Bowl
# ...        ...       ...                 ...
# 4610      1830         1       Steak Burrito
# 4611      1830         1      Veggie Burrito
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
#
#                                      choice_description  item_price
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 23    [[Tomatillo-Green Chili Salsa (Medium), Tomati...       10.98
# 39    [Roasted Chili Corn Salsa, [Fajita Vegetables,...       11.75
# ...

# %%
#Ver quantos produtos diferentes são
dataframe_novo2['item_name'].value_counts().shape[0]
# Out:
# 25

# %%
#Excluir do dataframe pedidos que tenham mesmo nome, choice description e quantidade - 715 pedidos distintos >10.0
#Excluir do dataframe pedidos que tenham mesmo nome e quantidade - 18 pedidos distintos >10.0
distintos = chipo.drop_duplicates(['item_name','quantity'])
distintos
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 3890      1559         2                  Carnitas Crispy Tacos
# 3973      1592         4                      Canned Soft Drink
# 4152      1660        10                          Bottled Water
# 4354      1738         2                       Steak Soft Tacos
# 4489      1786         4                    Chips and Guacamole
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
#Altera o tipo de dado da coluna item_price
distintos['item_price'] = distintos['item_price'].apply(lambda x: str(x).replace('$','')).astype('float64')
# Out:
# /home/joaovitorez/miniconda3/envs/env-data-handling/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
resultado = distintos[distintos.item_price/distintos.quantity > 10.0]
resultado
# Out:
#       order_id  quantity              item_name  \
# 5            3         1           Chicken Bowl
# 7            4         1          Steak Burrito
# 39          19         1          Barbacoa Bowl
# 57          26         1         Veggie Burrito
# 62          28         1            Veggie Bowl
# 135         60         2     Chicken Salad Bowl
# 168         75         1  Barbacoa Crispy Tacos
# 186         83         1      Veggie Salad Bowl
# 250        109         1          Chicken Salad
# 281        123         2       Steak Salad Bowl
# 409        178         3           Chicken Bowl
# 506        212         2          Carnitas Bowl
# 606        250         1       Steak Salad Bowl
# 738        304         1      Veggie Soft Tacos
# 1132       468         1    Carnitas Salad Bowl
# 1229       501         1    Barbacoa Salad Bowl
# 3480      1398         3          Carnitas Bowl
# 3601      1443         3         Veggie Burrito
#
# ...

# %%
len(resultado)
# Out:
# 18

# %% [markdown]
# ### Step 5. What is the price of each item?
# ###### print a data frame with only two columns item_name and item_price

# %%
#Fazer um dataframe com cada produto distinto, independentemente do preço
dataframe = pd.DataFrame({'item_name': distintos.item_name, 'item_´price': distintos.item_price/distintos.quantity})
dataframe #considerando repetições cujo choice description sejam diferentes, se fizermos value_counts, o resultado é 50
# Out:
#                                   item_name  item_´price
# 0              Chips and Fresh Tomato Salsa         2.39
# 1                                      Izze         3.39
# 2                          Nantucket Nectar         3.39
# 3     Chips and Tomatillo-Green Chili Salsa         2.39
# 4                              Chicken Bowl         8.49
# ...                                     ...          ...
# 3890                  Carnitas Crispy Tacos         8.99
# 3973                      Canned Soft Drink         1.25
# 4152                          Bottled Water         1.50
# 4354                       Steak Soft Tacos         9.25
# 4489                    Chips and Guacamole         4.45
#
# [103 rows x 2 columns]

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
dataframe.sort_values(by=['item_name'], ignore_index=True)
# Out:
#                  item_name  item_´price
# 0        6 Pack Soft Drink         6.49
# 1        6 Pack Soft Drink         6.49
# 2            Barbacoa Bowl        11.75
# 3         Barbacoa Burrito         8.99
# 4    Barbacoa Crispy Tacos         9.25
# ..                     ...          ...
# 98     Veggie Crispy Tacos         8.49
# 99            Veggie Salad         8.49
# 100      Veggie Salad Bowl        11.25
# 101      Veggie Soft Tacos         8.49
# 102      Veggie Soft Tacos        11.25
#
# [103 rows x 2 columns]

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
chipo.sort_values(by=['item_price'], ascending=False)
# Out:
#       order_id  quantity                     item_name  \
# 3598      1443        15  Chips and Fresh Tomato Salsa
# 3480      1398         3                 Carnitas Bowl
# 1254       511         4               Chicken Burrito
# 3602      1443         4               Chicken Burrito
# 3601      1443         3                Veggie Burrito
# ...        ...       ...                           ...
# 3936      1578         1                   Canned Soda
# 2922      1162         1                 Bottled Water
# 1396       567         1                   Canned Soda
# 2562      1014         1                   Canned Soda
# 1457       591         1                   Canned Soda
#
#                                      choice_description  item_price
# 3598                                                NaN       44.25
# 3480  [Roasted Chili Corn Salsa, [Fajita Vegetables,...       35.25
# 1254  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       35.00
# ...

# %% [markdown]
# ### Step 8. How many times was a Veggie Salad Bowl ordered?

# %% [markdown]
# ### Step 9. How many times did someone order more than one Canned Soda?
