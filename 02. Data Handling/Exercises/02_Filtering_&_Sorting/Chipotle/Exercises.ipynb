# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv", sep='\t')
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
chipo['item_price'] = chipo['item_price'].apply(lambda x: str(x).replace('$','')).astype('float64')

# %%
#Dentro do dataframe original, estou incluindo apenas os produtos cujo preço unitário (1qtd) seja maior que 10.0
dataframe_novo3 = chipo.loc[chipo['item_price']/chipo['quantity']>10.0]
dataframe_novo3
# Out:
#       order_id  quantity           item_name  \
# 5            3         1        Chicken Bowl
# 7            4         1       Steak Burrito
# 13           7         1        Chicken Bowl
# 23          12         1     Chicken Burrito
# 39          19         1       Barbacoa Bowl
# ...        ...       ...                 ...
# 4610      1830         1       Steak Burrito
# 4611      1830         1      Veggie Burrito
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
#
#                                      choice_description  item_price
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 23    [[Tomatillo-Green Chili Salsa (Medium), Tomati...       10.98
# 39    [Roasted Chili Corn Salsa, [Fajita Vegetables,...       11.75
# ...

# %%
#Do dataframe novo criado, tiro todos os itens que tenham qty+name+price duplicados
dataframe_novo3 = dataframe_novo3.drop_duplicates(subset=['quantity','item_name','item_price'])

# %%
#Produtos que custam mais de 10.0
dataframe_novo3.shape[0]
# Out:
# 62

# %% [markdown]
# ### Step 5. What is the price of each item?
# ###### print a data frame with only two columns item_name and item_price

# %%
#Distintos é o recorte do dataframe original 'chipo', contando apenas produtos distintos independente do preço
distintos = chipo.drop_duplicates(subset=['quantity','item_name','item_price'])
distintos
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4237      1691         2                    Chips and Guacamole
# 4354      1738         2                       Steak Soft Tacos
# 4489      1786         4                    Chips and Guacamole
# 4509      1793         1                                  Chips
# 4510      1793         1                          Barbacoa Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
distintos['item_price'] = distintos['item_price']/distintos['quantity']
# Out:
# /home/joaovitorez/miniconda3/envs/env-data-handling/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
distintos_redux = distintos.filter(['item_name','item_price'])
distintos_redux
# Out:
#                                   item_name  item_price
# 0              Chips and Fresh Tomato Salsa        2.39
# 1                                      Izze        3.39
# 2                          Nantucket Nectar        3.39
# 3     Chips and Tomatillo-Green Chili Salsa        2.39
# 4                              Chicken Bowl        8.49
# ...                                     ...         ...
# 4237                    Chips and Guacamole        4.25
# 4354                       Steak Soft Tacos        9.25
# 4489                    Chips and Guacamole        4.45
# 4509                                  Chips        1.99
# 4510                          Barbacoa Bowl       11.49
#
# [209 rows x 2 columns]

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
distintos_redux.sort_values(by=['item_name'], ignore_index=True)
# Out:
#              item_name  item_price
# 0    6 Pack Soft Drink        6.49
# 1    6 Pack Soft Drink        6.49
# 2        Barbacoa Bowl       11.49
# 3        Barbacoa Bowl        8.69
# 4        Barbacoa Bowl        9.25
# ..                 ...         ...
# 204  Veggie Salad Bowl       11.25
# 205  Veggie Soft Tacos        8.49
# 206  Veggie Soft Tacos       11.25
# 207  Veggie Soft Tacos        8.75
# 208  Veggie Soft Tacos        8.49
#
# [209 rows x 2 columns]

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
chipo.sort_values(by='item_price', ascending=False)
# Out:
#       order_id  quantity                     item_name  \
# 3598      1443        15  Chips and Fresh Tomato Salsa
# 3480      1398         3                 Carnitas Bowl
# 1254       511         4               Chicken Burrito
# 3602      1443         4               Chicken Burrito
# 3601      1443         3                Veggie Burrito
# ...        ...       ...                           ...
# 3936      1578         1                   Canned Soda
# 2922      1162         1                 Bottled Water
# 1396       567         1                   Canned Soda
# 2562      1014         1                   Canned Soda
# 1457       591         1                   Canned Soda
#
#                                      choice_description  item_price
# 3598                                                NaN       44.25
# 3480  [Roasted Chili Corn Salsa, [Fajita Vegetables,...       35.25
# 1254  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       35.00
# ...

# %%
chipo.sort_values(by='item_price', ascending=False).loc[3598,'quantity']

#Deve ter um jeito mais fácil de fazer isso
# Out:
# 15

# %% [markdown]
# ### Step 8. How many times was a Veggie Salad Bowl ordered?

# %%
dataframe_novo3['item_name'].value_counts()['Veggie Salad Bowl']
# Out:
# 1

# %% [markdown]
# ### Step 9. How many times did someone order more than one Canned Soda?

# %%
chipo['quantity'] = chipo['quantity'].astype('float64')

# %%
novo_chipo = chipo[chipo.quantity>2]

# %%
novo_chipo[novo_chipo['item_name']=='Canned Soda']
# Out:
#       order_id  quantity    item_name choice_description  item_price
# 18           9       9.0  Canned Soda           [Sprite]        2.18
# 51          23      23.0  Canned Soda     [Mountain Dew]        2.18
# 162         73      73.0  Canned Soda        [Diet Coke]        2.18
# 171         76      76.0  Canned Soda  [Diet Dr. Pepper]        2.18
# 350        150     150.0  Canned Soda        [Diet Coke]        2.18
# 352        151     151.0  Canned Soda        [Coca Cola]        2.18
# 698        287     287.0  Canned Soda        [Coca Cola]        2.18
# 700        288     288.0  Canned Soda        [Coca Cola]        2.18
# 909        376     376.0  Canned Soda     [Mountain Dew]        2.18
# 1091       450     450.0  Canned Soda       [Dr. Pepper]        2.18
# 1092       450     450.0  Canned Soda        [Coca Cola]        2.18
# 1944       787     787.0  Canned Soda       [Dr. Pepper]        2.18
# 2135       859     859.0  Canned Soda        [Diet Coke]        2.18
# ...

# %%
len(novo_chipo[novo_chipo['item_name']=='Canned Soda'])
# Out:
# 20
